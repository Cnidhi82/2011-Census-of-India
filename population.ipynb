# %%
# Import the appropriate libraries
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


census_df=pd.read_csv(r"C:\Users\nidhi\OneDrive\Desktop\Launch_code_projects\2011-Census-of-India\population.csv")

# %%
census_df.head(35)
# Out:
#     Rank                        State             Capital   Population  \
# 0      1                Uttar Pradesh             Lucknow  199,812,341
# 1      2                  Maharashtra              Mumbai  112,374,333
# 2      3                        Bihar               Patna  104,099,452
# 3      4                  West Bengal             Kolkata   91,276,115
# 4      5               Andhra Pradesh           Hyderabad   84,580,777
# 5      6               Madhya Pradesh              Bhopal   72,626,809
# 6      7                   Tamil Nadu             Chennai   72,147,030
# 7      8                    Rajasthan              Jaipur   68,548,437
# 8      9                    Karnataka           Bengaluru   61,095,297
# 9     10                      Gujarat         Gandhinagar   60,439,692
# 10    11                       Odisha        Bhubaneshwar   41,974,218
# 11    12                       Kerala  Thiruvananthapuram   33,406,061
# ...

# %%
census_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   35 non-null     int64
#  1   State                  35 non-null     object
#  2   Capital                34 non-null     object
#  3   Population             35 non-null     object
#  4   % of Total Population  35 non-null     float64
#  5   Males                  35 non-null     object
#  6   Females                35 non-null     object
#  7   Sex Ratio              35 non-null     object
#  8   Literacy Rate (%)      35 non-null     float64
#  9   Rural Population       35 non-null     object
#  10  Urban Population       35 non-null     object
#  11  Area (km*km)           35 non-null     object
#  12  Density (1/km*km)      35 non-null     object
#  13  Decadal Growth (%)     35 non-null     object
# dtypes: float64(2), int64(1), object(11)
# ...

# %%
census_df["State"].nunique()
# Out:
# 35

# %%
census_df.describe()
# Out:
#             Rank  % of Total Population  Literacy Rate (%)
# count  35.000000              35.000000          35.000000
# mean   18.000000               2.856857          77.940286
# std    10.246951               3.671943           8.598837
# min     1.000000               0.010000          61.800000
# 25%     9.500000               0.115000          71.235000
# 50%    18.000000               1.390000          78.030000
# 75%    26.500000               5.020000          85.950000
# max    35.000000              16.500000          94.000000

# %%
census_df.columns
# Out:
# Index(['Rank', 'State', 'Capital', 'Population', '% of Total Population',
#        'Males', 'Females', 'Sex Ratio', 'Literacy Rate (%)',
#        'Rural Population', 'Urban Population', 'Area (km*km)',
#        'Density (1/km*km)', 'Decadal Growth (%)'],
#       dtype='object')

# %%
census_df['Population'] = census_df['Population'].str.replace(',','', regex=True).astype(float)
census_df['Males'] = census_df['Males'].str.replace(',','', regex=True).astype(float)
census_df['Females'] = census_df['Females'].str.replace(',','', regex=True).astype(float)
census_df['Rural Population'] = census_df['Rural Population'].str.replace(',','', regex=True).astype(float)
census_df['Urban Population'] = census_df['Urban Population'].str.replace(',','', regex=True).astype(float)
census_df['Sex Ratio'] = census_df['Sex Ratio'].str.replace(',','', regex=True).astype(float)
census_df['Area (km*km)'] = census_df['Area (km*km)'].str.replace(',','', regex=True).astype(float)
census_df['Density (1/km*km)'] = census_df['Density (1/km*km)'].str.replace(',','', regex=True).astype(float)
#census_df['Decadal Growth (%)'] = census_df['Decadal Growth (%)'].str.strip('%')
#census_df['Decadal Growth (%)'] = census_df['Decadal Growth (%)'].str.replace('%', '',regex=True)
#census_df['Decadal Growth (%)'] = census_df['Decadal Growth (%)'].str.replace('\U00002013', '-',regex=True)

census_df.loc[census_df['State'] == 'Jammu and Kashmir', 'Capital'] = 'Srinagar'

census_df_clean = census_df.copy()

# %%
census_df.head(35)
# Out:
#     Rank                        State             Capital   Population  \
# 0      1                Uttar Pradesh             Lucknow  199812341.0
# 1      2                  Maharashtra              Mumbai  112374333.0
# 2      3                        Bihar               Patna  104099452.0
# 3      4                  West Bengal             Kolkata   91276115.0
# 4      5               Andhra Pradesh           Hyderabad   84580777.0
# 5      6               Madhya Pradesh              Bhopal   72626809.0
# 6      7                   Tamil Nadu             Chennai   72147030.0
# 7      8                    Rajasthan              Jaipur   68548437.0
# 8      9                    Karnataka           Bengaluru   61095297.0
# 9     10                      Gujarat         Gandhinagar   60439692.0
# 10    11                       Odisha        Bhubaneshwar   41974218.0
# 11    12                       Kerala  Thiruvananthapuram   33406061.0
# ...

# %%
census_df_clean = census_df.copy()

# %%
census_df.head()
# Out:
#    Rank           State    Capital   Population  % of Total Population  \
# 0     1   Uttar Pradesh    Lucknow  199812341.0                  16.50
# 1     2     Maharashtra     Mumbai  112374333.0                   9.28
# 2     3           Bihar      Patna  104099452.0                   8.60
# 3     4     West Bengal    Kolkata   91276115.0                   7.54
# 4     5  Andhra Pradesh  Hyderabad   84580777.0                   6.99
#
#          Males     Females  Sex Ratio  Literacy Rate (%)  Rural Population  \
# 0  104480510.0  95331831.0      912.0              67.68       155111022.0
# 1   58243056.0  54131277.0      929.0              82.34        61545441.0
# 2   54278157.0  49821295.0      918.0              61.80        92075028.0
# 3   46809027.0  44467088.0      950.0              76.26        62213676.0
# 4   42442146.0  42138631.0      993.0              67.02        56361702.0
#
#    Urban Population  Area (km*km)  Density (1/km*km) Decadal Growth (%)
# ...

# %%
def convert_to_float(x):
    x = x.replace("−", "-")
    return float(x.strip('%'))

census_df_clean['Decadal Growth (%)'] = census_df_clean['Decadal Growth (%)'].apply(convert_to_float)

# %%
census_df_clean.dtypes
# Out:
# Rank                       int64
# State                     object
# Capital                   object
# Population               float64
# % of Total Population    float64
# Males                    float64
# Females                  float64
# Sex Ratio                float64
# Literacy Rate (%)        float64
# Rural Population         float64
# Urban Population         float64
# Area (km*km)             float64
# Density (1/km*km)        float64
# Decadal Growth (%)       float64
# dtype: object

# %%
census_df_clean.head()
# Out:
#    Rank           State    Capital   Population  % of Total Population  \
# 0     1   Uttar Pradesh    Lucknow  199812341.0                  16.50
# 1     2     Maharashtra     Mumbai  112374333.0                   9.28
# 2     3           Bihar      Patna  104099452.0                   8.60
# 3     4     West Bengal    Kolkata   91276115.0                   7.54
# 4     5  Andhra Pradesh  Hyderabad   84580777.0                   6.99
#
#          Males     Females  Sex Ratio  Literacy Rate (%)  Rural Population  \
# 0  104480510.0  95331831.0      912.0              67.68       155111022.0
# 1   58243056.0  54131277.0      929.0              82.34        61545441.0
# 2   54278157.0  49821295.0      918.0              61.80        92075028.0
# 3   46809027.0  44467088.0      950.0              76.26        62213676.0
# 4   42442146.0  42138631.0      993.0              67.02        56361702.0
#
#    Urban Population  Area (km*km)  Density (1/km*km)  Decadal Growth (%)
# ...

# %%
Population = census_df['Population'].head(12)
State = census_df['State'].head(12)
 
# Figure Size
fig = plt.figure(figsize =(50, 10))
 
# Horizontal Bar Plot
plt.bar(State[0:35], Population[0:35])
 
# Show Plot
plt.show()
